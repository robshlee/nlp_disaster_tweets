# %% [markdown]
# # Real or Not? NLP with Disaster Tweets
# In this notebook I'll be using NLP to predict whether tweets are about real disasters or not. The dataset comes from a Kaggle competetion found here: https://www.kaggle.com/c/nlp-getting-started/overview.
#
# The competition is based on F1 scores so we'll work to optimize that.

# %%
# imports
import pandas as pd
import numpy as np
import math

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import RidgeClassifier

# %%
# import data
data = pd.read_csv('./dataset/train.csv')

# %% [markdown]
# # EDA

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(data[['keyword','location','text']]
                                                   ,data[['target']]
                                                   ,random_state=42)

# targets as 1d array
y_train_array = y_train.values.reshape(-1)
y_test_array = y_test.values.reshape(-1)

# %%
# number of rows
print(f'Rows of data: {x_train.shape[0]}')

# baseline accuracy
baseline = round(np.mean(y_train), 2)
print(f'Baseline accuracy: {baseline}')

# sneak peak at data
data.head()
# Out:
# Rows of data: 5709
# Baseline accuracy: target    0.43
# dtype: float64
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# show attributes as grid (so we can better scan more attributes)
keywords = np.array(x_train.groupby('keyword').count().index)
keywords_grid = arr_to_grid(keywords)

locations = np.array(x_train.groupby('location').count().index)
locations_grid = arr_to_grid(locations)

# print count of unique keywords and locations
print(f'Count of unique keywords: {len(keywords)}')
print(f'Count of unique locations: {len(locations)}')
# Out:
# Count of unique keywords: 221
# Count of unique locations: 2619

# %%
keywords_grid
# Out:
#                       0               1                   2  \
# 0                ablaze        accident          aftershock
# 1                 arson        arsonist              attack
# 2              bleeding         blew up              blight
# 3                  bomb          bombed             bombing
# 4            casualties        casualty         catastrophe
# 5             collision           crash             crashed
# 6                 death          deaths              debris
# 7            derailment        desolate          desolation
# 8              disaster       displaced             drought
# 9             emergency  emergency plan  emergency services
# 10            explosion      eyewitness              famine
# 11               flames       flattened               flood
# 12               hazard       hazardous           heat wave
# 13              injured        injuries              injury
# 14        mass murderer        massacre              mayhem
# 15          obliterated    obliteration           oil spill
# 16  radiation emergency       rainstorm               razed
# 17                 ruin       sandstorm            screamed
# 18                smoke       snowstorm               storm
# 19             survived       survivors           terrorism
# 20               trauma     traumatised             trouble
# 21               weapon         weapons           whirlwind
# 22              wrecked               -                   -
#
#                     3                   4                  5  \
# 0   airplane accident           ambulance        annihilated
# 1            attacked           avalanche             battle
# 2            blizzard               blood             bloody
# 3     bridge collapse   buildings burning  buildings on fire
# 4        catastrophic  chemical emergency         cliff fall
# 5               crush             crushed             curfew
# 6              deluge             deluged           demolish
# 7             destroy           destroyed        destruction
# 8               drown             drowned           drowning
# 9            engulfed           epicentre           evacuate
# 10              fatal          fatalities           fatality
# 11           flooding              floods        forest fire
# 12           hellfire              hijack           hijacker
# 13          inundated          inundation          landslide
# 14           meltdown            military           mudslide
# 15           outbreak         pandemonium              panic
# 16           refugees              rescue            rescued
# 17          screaming             screams            seismic
# 18          stretcher  structural failure       suicide bomb
# 19          terrorist              threat            thunder
# 20            tsunami             twister            typhoon
# 21         wild fires            wildfire          windstorm
# 22                  -                   -                  -
#
#                    6                 7                  8                 9
# 0       annihilation        apocalypse         armageddon              army
# 1          bioterror      bioterrorism              blaze           blazing
# 2           blown up          body bag       body bagging         body bags
# 3             burned           burning  burning buildings        bush fires
# 4           collapse         collapsed            collide          collided
# 5            cyclone            damage             danger              dead
# 6         demolished        demolition             derail          derailed
# 7           detonate        detonation         devastated       devastation
# 8         dust storm        earthquake        electrocute      electrocuted
# 9          evacuated        evacuation            explode          exploded
# 10              fear              fire         fire truck  first responders
# 11      forest fires              hail          hailstorm              harm
# 12         hijacking           hostage           hostages         hurricane
# 13              lava         lightning          loud bang       mass murder
# 14  natural disaster  nuclear disaster    nuclear reactor        obliterate
# 15         panicking            police         quarantine       quarantined
# 16          rescuers              riot            rioting            rubble
# 17          sinkhole           sinking              siren            sirens
# 18    suicide bomber   suicide bombing               sunk           survive
# 19      thunderstorm           tornado            tragedy           trapped
# 20          upheaval     violent storm            volcano          war zone
# 21           wounded            wounds              wreck          wreckage
# 22                 -                 -                  -                 -

# %%
locations_grid
# Out:
#                                   0  \
# 0
# 1                   Baku & Erzurum
# 2     Road to the Billionaires Club
# 3                  #FLIGHTCITY UK
# 4              #SOUTHAMPTON ENGLAND
# 5                 'SAN ANTONIOOOOO'
# 6          10 Steps Ahead.  Cloud 9
# 7                         18 Û¢ CC
# 8                               253
# 9                    3rd Eye Chakra
# 10                              627
# 11                              956
# 12                      ??+ ... ??+
# 13                  ????? ???? ????
# 14         ?????????????, Thailand
# 15                 A Hoop Somewhere
# 16                        ARGENTINA
# 17          Aarhus, Central Jutland
# 18                         Adelaide
# 19                          Alabama
# 20           Albuquerque New Mexico
# 21     Alphen aan den Rijn, Holland
# 22                     Amman,Jordan
# 23                         Anywhere
# 24                    Arlington, TX
# 25    Ashford, Kent, United Kingdom
# 26                 Atlanta Georgia
# 27                          Auburn
# 28               Austin/Los Angeles
# 29                    BOSTON-LONDON
# ..                              ...
# 232             central chazifornia
# 233                          cyprus
# 234                          dubai
# 235                        eritrean
# 236         gamertag: bexrayandvav
# 237                  hertfordshire.
# 238                       hyderabad
# 239                  icon: cheese3d
# 240          instagram- Chloe_Bellx
# 241                          khanna
# 242        livin in a plastic world
# 243   lrhcthband;four - bournemouth
# 244                         midwest
# 245                              nc
# 246                              ny
# 247                          oxford
# 248                     planeta H2o
# 249           proudly South African
# 250                      seattle wa
# 251                  somewhere USA
# 252       st.louis county missouri
# 253                         texasss
# 254                       they/them
# 255   tripoli international airport
# 256           walking the tightrope
# 257                         whs '17
# 258         www.twitch.tv/PKSparkxx
# 259             || c h i c a g o ||
# 260         ÌÏT: 1.50225,103.742992
# 261       ÌÏT: 42.910975,-78.865828
#
#                                               1                            2  \
# 0                          Melbourne, Australia                         News
# 1                                Eugene, Oregon                 Jariana Town
# 2                                    Somewhere.                    The World
# 3                            #ForeverWithBAP 8    #Gladiator Û¢860Û¢757Û¢
# 4                                  #SandraBland               #WhereverI'mAt
# 5                               ( ?å¡ ?? ?å¡),                          (RP)
# 6                            107-18 79TH STREET                      11/4/14
# 7                         19.600858, -99.047821               1D | 5SOS | AG
# 8                  261 5th Avenue New York, NY     2B Hindhede Rd, Singapore
# 9                                    401 livin'  412 NW 5th Ave. Portland OR
# 15                 A.A.S my Aztec Princess                   ACCRA GHANA
# 16                                 ATL, GA                     ATL??AL??
# 17          Above the snake line - #YoNews                   Absecon, NJ
# 18              Adventist - Lesson Sabbath         Adventuring in Narnia
# 19                                  Alaska                     Albany/NY
# 20                     Alexandria, VA, USA  Alger-New York-San Francisco
# 21                        Am International                      Amarillo
# 22               Amsterdam | San Francisco        An eight-sided polygon
# 23          Aperture Science Test Facility             Aracaju - Sergipe
# 24                 Arnhem, the Netherlands                     Arthas US
# 25                                    Asia                  At your back
# 26                             Atlanta, Ga              Atlanta, Georgia
# 27                   Auckland, New Zealand                   Augusta, GA
# 28                        Aveiro, Portugal                      Avon, OH
# 29                         Back East in PA                         Bacon
# ..                                     ...                           ...
# 232                                  china      cody, austin follows ?*?
# 233                                denmark               denver colorado
# 234                        dundalk ireland                       eARth 3
# 235            facebook.com/tradcatknights                      far away
# 236          golborne, north west england.                    guaravitas
# 237                              hkXfYMhEx                         home
# 238                           i luv raquel    i'm a Citizen of the World
# 239         im definitely taller than you.             in Dimitri's arms
# 240         jayankondacholapuram.tamilnadu             jeddah | Khartoum
# 241                            labyrinthia                 lagos nigeria
# 242                                 london                 london town..
# 243              marvel | books | hp | tmr                      maryland
# 244                           missouri USA                           mnl
# 245                               new york                  new york, ny
# 246                   oman muscat al seeb         on a catwalk somewhere
# 247                     peshawar pakistan                pettyville, usa
# 248                               plymouth               port matilda pa
# 249                      rural ohio (fuck)                        russia
# 250                                sindria                    sisterhood
# 251                      somewhere outside     somewhere too cold for me
# 252                                swindon             sydney, australia
# 253                        the azure cloud                    the burrow
# 254                                  tokyo                        toledo
# 255                                     tx                            uk
# 256                        we?it Û¢ ixwin  westwestwestwestwestwestwest
# 257                                    wny                         world
# 258                                  y/e/l                   yorkshire\n
# 259  Û¢5Û¢12Û¢14Û¢ | åÈ#SaviourSquadåÇ                     Û¢FLGÛ¢
# 260            ÌÏT: 27.9136024,-81.6078532     ÌÏT: 30.307558,-81.403118
# 261          ÌøåÀå_T: 40.736324,-73.990062               å_: ?? ÌÑ ? : ?
#
#                                                 5  \
# 0                   ? ??????? ? ( ?? å¡ ? ? ? å¡)
# 1                                      New Delhi
# 2                            |IG: imaginedragoner
# 3                        #KaumElite;#F?VOR;#SMOFC
# 4                                      #iminchina
# 5                                     -?s?s?j??s-
# 6                    1313 W.Patrick St, Frederick
# 7                           204, 555 11 Ave. S.W.
# 8                                     302???? 815
# 9                              48.870833,2.399227
# 10    828/704(Soufside)/while looking goofy in NJ
# 11                                      ?205?478?
# 12                         ??? ??? ????? ??? ???.
# 13                             ???????, ??'??????
# 14                               ?s????ss? a?????
# 15                                            AEP
# 16                             ATLANTA , GEORGIA
# 17                                          Abuja
# 18                                    Afghanistan
# 19                                       Alberta
# 20                           All Around the World
# 21                   Amazon Seller , Propagandist
# 22                                        Anaheim
# 23                                        Area 8
# 24                                     Arvada, CO
# 25                               Athens - Nicosia
# 26                           Atlanta, Georgia USA
# 27                               Aurora, Ontario
# 28                                        Azeroth
# 29                        Bakersfield, California
# ..                                            ...
# 232                     cognitive dissonance town
# 233                 dmv ?? fashion school @ KSU.
# 234                         eBooks, North America
# 235                                            fl
# 236                                           h+l
# 237                              honeymoon avenue
# 238                 iPhone: -27.499212,153.011072
# 239                                    in my head
# 240                                       jersey
# 241                            laying on the bass
# 242                               los angeles, ca
# 243                                marysville ca
# 244                                        mpls.
# 245                                      ngapain?
# 246                                     on the go
# 247                                            ph
# 248                                   potters bar
# 249                                         rzl ?
# 250                 sitting on Eddie Vedders lap,
# 251                     south africa eastern cape
# 252                                     sÌ£o luis
# 253                           the insane asylum.
# 254                                       too far
# 255                             under the blanket
# 256                      where I'm supposed to be
# 257                                     worldwide
# 258  youtube.com/channel/UCHWTLC9B4ZjUGh7yDlb55Iw
# 259                            Û¢III.XII.MMXIÛ¢
# 260                     ÌÏT: 33.209923,-87.545328
# 261                          å_å_Los Mina Cityã¢
#
#                                   6  \
# 0        ?currently writing a book?
# 1                       New England
# 2    #1 Vacation Destination,HAWAII
# 3            #NewcastleuponTyne #UK
# 4                 #keepthefaith J&J
# 5                      ... -.- -.--
# 6                      14/cis/istj
# 7                          21 | PNW
# 8                               304
# 9     5/5 access / rt link please x
# 10                    828??864??803
# 11                               ??
# 12                  ??? ???? ??????
# 13                   ???????, Texas
# 14        ?semekeepschanging@soyeh?
# 15                           AFRICA
# 16                              ATX
# 17                   Abuja, Nigeria
# 18                           Africa
# 19                     Alberta Pack
# 20             All around the world
# 21                          America
# 22                    Anchorage, AK
# 23                        Argentina
# 24                           Asgard
# 25                   Athens, Greece
# 26                       Atlanta,Ga
# 27                           Austin
# 28                         Aztec NM
# 29            Balikesir - Eskisehir
# ..                              ...
# 232                   columbus ohio
# 233               don't buy the s*n
# 234   eating strawberry shitsickles
# 235                    fluffy cloud
# 236           have car; will travel
# 237                          houstn
# 238    iPhone: 33.104393,-96.628624
# 239      in my own personal hell (:
# 240      justin & ari follow || tvd
# 241                      lee london
# 242                 lost in history
# 243                       melbourne
# 244                          mumbai
# 245                         nigeria
# 246                      on the web
# 247                         philly
# 248               probably not home
# 249            san gabriel la union
# 250  sitting on the fence, New York
# 251                south of heaven
# 252            taken by piper curda
# 253                        the moon
# 254                toronto, ontario
# 255                         urÌ£nus
# 256       where the wild things are
# 257      wrapped arnd hyuk's finger
# 258      zboyer@washingtontimes.com
# 259           Û¢OlderCandyBloomÛ¢
# 260       ÌÏT: 35.223347,-80.827834
# 261              å¡å¡Midwest Û¢Û¢
#
#                                               7  \
# 0                                       Alberta
# 1                                       Nxgerxa
# 2                                 #????? Libya#
# 3                                          #ODU
# 4                               #otrakansascity
# 5                                        //??//
# 6                 140920-21 & 150718-19 BEIJING
# 7                                     21, Porto
# 8                                       36 & 38
# 9                  570 Vanderbilt; Brooklyn, NY
# 10                                 876 Jamrock.
# 11            ?? ?+254? ? \??å¡_??å¡_???å¡_?/??
# 12                                         ????
# 13                                  ???????????
# 14                     @UntmdOutdoors #T.O.R.K
# 15                               AKRON OHIO USA
# 16                                          AUS
# 238                    iTunes - RSS               iamdigitalent.com
# 239                           india                         indiana
# 240                          keli x                           kenya
# 241              liaÛ¢daniÛ¢laura                      liverpool
# 242            louisville, kentucky                       lowestoft
# 243                           miami                 miami x dallas
# 244                         my deli                       nap queen
# 245                           nj/ny                  not so cool KY
# 246          ona block w/ my BOY ??                         online
# 247                       pittsboro                    planet earth
# 248         probably the strip club      probably watching survivor
# 249                     scandinavia                    scumbernauld
# 250    sneaking glances at Thancred        someplace living my life
# 251                       sri lanka                              ss
# 252       taking pain like pleasure                           texas
# 253                 the void, U.S.A                        they/her
# 254       travelling to tae's pants                       tri state
# 255                              va                   vancouver usa
# 256        wherever there's netflix    wherever-the-fuck washington
# 257        www.facebook.com/stuntfm                www.tmgcgart.com
# 258        {GoT | Modern AU | Lizz}                             |-/
# 259       ÌÏT: -26.695807,27.837865                    ÌÏT: 0.0,0.0
# 260       ÌÏT: 40.707762,-74.014213       ÌÏT: 41.252426,-96.072013
# 261                     åø\_(?)_/åø                               -
#
# [262 rows x 10 columns]

# %%
# sample of disaster
print(f'This is a disaster tweet: {data[data.target==1].iloc[0].text}\n')

# sample of non-disaster
print(f'This is a non-disaster tweet: {data[data.target==0].iloc[0].text}')
# Out:
# This is a disaster tweet: Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
#
# This is a non-disaster tweet: What's up man?

# %% [markdown]
# The examples we see look quite obvious whether the tweet is about a disaster or not. There may be examples where the tweet may not be so obvious especially if non-contentional words are being used to describe the disaster or if a word used for a disaster is used in a more casual way. An example of a tweet that contains a 'disaster' word but wouldn't indicate a disaster may be "I wonder if earthquakes are common in the North Pole".

# %% [markdown]
# # Modeling

# %%
# use count vectorizer to vectorize text
cv = CountVectorizer()
train_vectors = cv.fit_transform(x_train['text'])

# we're NOT using .fit_transform() but rather .transform() to ensure tokens in the train
# vectors are the only ones mapped to the test vectors.
test_vectors = cv.transform(x_test['text'])

# %%
# we'll start with a linear model
# because our vectors are really big, we want to push the model's weights toward 0 without
# completely discounting different words. Ridge regression is a good way to do this.
ridge = RidgeClassifier()

# cross validate
scores = cross_val_score(ridge, train_vectors, y_train_array, cv=3, scoring='f1')
print(f'Avg cross validation score: {np.mean(scores)}')
# Out:
# Avg cross validation score: 0.7197266631555141

# %% [markdown]
# With our first model we received a cross validation score of 0.72 which isn't too bad. Let's try to fit the data to more complex models and see if we can get a better f1 score.

# %%
ridge.fit(train_vectors, y_train_array)
# Out:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, normalize=False, random_state=None,
#                 solver='auto', tol=0.001)

# %%
# predictions on test set
pred = ridge.predict(test_vectors)
score = ridge.score(test_vectors, y_test_array)

# score
print(f'Test prediction score: {score}')

# confusion matrix
cm = pd.DataFrame(confusion_matrix(y_test, pred))
cm.columns = ['pred disaster','pred not disaster']
cm.index = ['actual disaster','actual not disaster']

cm
# Out:
# Test prediction score: 0.7909663865546218
#                      pred disaster  pred not disaster
# actual disaster                929                162
# actual not disaster            236                577

# %%
# classification report
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82      1091
#            1       0.78      0.71      0.74       813
#
#     accuracy                           0.79      1904
#    macro avg       0.79      0.78      0.78      1904
# weighted avg       0.79      0.79      0.79      1904
